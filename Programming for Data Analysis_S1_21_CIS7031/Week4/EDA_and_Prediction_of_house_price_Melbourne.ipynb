# %%
# EDA and Predict house price using Predictive model.

# %%
import pandas as pd

# %%
df=pd.read_csv("melb_data.csv")

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1  1.0       202           NaN
# 1  4/02/2016       2.5      3067  ...         1  0.0       156          79.0
# 2  4/03/2017       2.5      3067  ...         2  0.0       134         150.0
# 3  4/03/2017       2.5      3067  ...         2  1.0        94           NaN
# 4  4/06/2016       2.5      3067  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
len(df) #to get how many rows we have in our datadrame.
# Out:
# 13580

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
# ...

# %%
df.dropna(axis=0, inplace=True)

# %%
df.head()
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin  4/02/2016
# 2  Abbotsford     5 Charles St      3    h  1465000     SP  Biggin  4/03/2017
# 4  Abbotsford      55a Park St      4    h  1600000     VB  Nelson  4/06/2016
# 6  Abbotsford     124 Yarra St      3    h  1876000      S  Nelson  7/05/2016
# 7  Abbotsford    98 Charles St      2    h  1636000      S  Nelson  8/10/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 1       2.5      3067  ...         1  0.0       156          79.0     1900.0
# 2       2.5      3067  ...         2  0.0       134         150.0     1900.0
# 4       2.5      3067  ...         1  2.0       120         142.0     2014.0
# 6       2.5      3067  ...         2  0.0       245         210.0     1910.0
# 7       2.5      3067  ...         1  2.0       256         107.0     1890.0
#
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of              Suburb          Address  Rooms Type    Price Method  \
# 1        Abbotsford  25 Bloomburg St      2    h  1035000      S
# 2        Abbotsford     5 Charles St      3    h  1465000     SP
# 4        Abbotsford      55a Park St      4    h  1600000     VB
# 6        Abbotsford     124 Yarra St      3    h  1876000      S
# 7        Abbotsford    98 Charles St      2    h  1636000      S
# ...             ...              ...    ...  ...      ...    ...
# 12205    Whittlesea    30 Sherwin St      3    h   601000      S
# 12206  Williamstown      75 Cecil St      3    h  1050000     VB
# 12207  Williamstown    2/29 Dover Rd      1    u   385000     SP
# 12209       Windsor  201/152 Peel St      2    u   560000     PI
# 12212    Yarraville  54 Pentland Pde      6    h  2450000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   4/02/2016       2.5      3067  ...         1  0.0
# ...

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.head(2)
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin  4/02/2016
# 2  Abbotsford     5 Charles St      3    h  1465000     SP  Biggin  4/03/2017
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 1       2.5      3067  ...         1  0.0       156          79.0     1900.0
# 2       2.5      3067  ...         2  0.0       134         150.0     1900.0
#
#    CouncilArea Lattitude  Longtitude             Regionname Propertycount
# 1        Yarra  -37.8079    144.9934  Northern Metropolitan          4019
# 2        Yarra  -37.8093    144.9944  Northern Metropolitan          4019
#
# [2 rows x 21 columns]

# %%
y=df["Price"] #this is going to be our dependent variable(output)

# %%
y.head()
# Out:
# 1    1035000
# 2    1465000
# 4    1600000
# 6    1876000
# 7    1636000
# Name: Price, dtype: int64

# %%
features=["Rooms", "Bathroom", "Landsize", "Lattitude", "Longtitude"]

# %%
features
# Out:
# ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
x=df[features] #it would be our independents variables or inputs

# %%
x.head()
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2         1       156   -37.8079    144.9934
# 2      3         2       134   -37.8093    144.9944
# 4      4         1       120   -37.8072    144.9941
# 6      3         2       245   -37.8024    144.9993
# 7      2         1       256   -37.8060    144.9954

# %%
x.describe()
# Out:
#              Rooms     Bathroom      Landsize    Lattitude   Longtitude
# count  6196.000000  6196.000000   6196.000000  6196.000000  6196.000000
# mean      2.931407     1.576340    471.006940   -37.807904   144.990201
# std       0.971079     0.711362    897.449881     0.075850     0.099165
# min       1.000000     1.000000      0.000000   -38.164920   144.542370
# 25%       2.000000     1.000000    152.000000   -37.855438   144.926198
# 50%       3.000000     1.000000    373.000000   -37.802250   144.995800
# 75%       4.000000     2.000000    628.000000   -37.758200   145.052700
# max       8.000000     8.000000  37000.000000   -37.457090   145.526350

# %%
from sklearn.tree import DecisionTreeRegressor as dtg # i'm using DecisionTreeRegressor form sklearn.tree. 
#we can use this supervised ML algorthm for regreesion and classification problem.

# %%
model=dtg(random_state=1)

# %%
model.fit(x,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=1, splitter='best')

# %%
# to get top 10 number of prediction prices of house from datasets

# %%
print("Making predictions for the following 5 houses:")
print(x.head(10))
print("The predictions are")
print(model.predict(x.head(10)))
# Out:
# Making predictions for the following 5 houses:
#     Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1       2         1       156   -37.8079    144.9934
# 2       3         2       134   -37.8093    144.9944
# 4       4         1       120   -37.8072    144.9941
# 6       3         2       245   -37.8024    144.9993
# 7       2         1       256   -37.8060    144.9954
# 9       2         1       220   -37.8010    144.9989
# 11      3         2       214   -37.8085    144.9964
# 12      2         2         0   -37.8078    144.9965
# 15      2         1       238   -37.8090    144.9976
# 16      3         2       113   -37.8056    144.9930
# The predictions are
# [1035000. 1465000. 1600000. 1876000. 1636000. 1097000. 1350000.  750000.
#  1310000. 1200000.]
